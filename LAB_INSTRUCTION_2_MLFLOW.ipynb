# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration
#
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.
#
# You have two options for running MLflow:
#
# #### Option 1: Local MLflow (Simple)
# 1. Open terminal - we recommend to split it into 2 shells or just open additional session.
#
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5001
# ```
#
#
# **Important: Keep this terminal window open.** The MLflow server will continue running and be accessible at http://localhost:5001
#
# #### Option 2: MLflow with Docker (Recommended for production-like setup)
#
# 1. Create a `docker-compose.yml` file:
# ```yaml
# services:
#   mlflow:
#     image: ghcr.io/mlflow/mlflow:v2.9.2
#     container_name: mlflow-server
#     ports:
#       - "5001:5000"
#     volumes:
#       - ./mlflow-data:/mlflow
#     command:
#       - mlflow
#       - server
#       - --backend-store-uri
#       - sqlite:////mlflow/mlflow.db
#       - --default-artifact-root
#       - /mlflow/artifacts
#       - --host
#       - 0.0.0.0
#       - --port
#       - "5000"
#     restart: unless-stopped
# ```
#
# 2. Start MLflow with Docker:
# ```bash
# docker compose down -v
# rm -rf mlflow-data
# mkdir -p mlflow-data/artifacts
# docker compose up -d
# ```
#
# 3. Check if it's running:
# ```bash
# docker-compose ps
# ```
#
# 4. View logs (optional):
# ```bash
# docker-compose logs -f mlflow
# ```
#
# 5. To stop the server later:
# ```bash
# docker-compose down
# ```
#
# **Important: Add MLflow files to .gitignore**
#
# MLflow creates local files that should not be committed to Git. Add these lines to your `.gitignore`:
#
# ```
# # MLflow
# mlflow.db
# mlflow-artifacts/
# mlruns/
# ```
#
# These files contain experiment data and artifacts that are specific to your local machine. In production, you would use a remote tracking server and artifact storage (like S3).

# %% [markdown]
# ### Connecting to MLflow
#
# To verify if the server runs properly, let's connect to it:
#
# ```python
# import mlflow
# import mlflow.sklearn
#
# import warnings
#
# warnings.filterwarnings("ignore")
#
# mlflow.set_tracking_uri("http://localhost:5001")
# print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# ```
#
# **To stop the MLflow server later:**
#
# - **Local setup**: Press `Ctrl+C` in the terminal where it's running
# - **Docker setup**: Run `docker-compose down`
#
# The server will shut down gracefully and save all your experiments.
#
# **Note:** Keep the server running throughout this lab session. All your experiments will be logged to this server instance.

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5001")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5001

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

# As we have temporal data, the best way to evaluate our model is time (chronological) 
# split, where the newest data is used for testing. We will assume that we have the 
# data #for years 2006 and 2007, and evaluate using data from 2008.

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a bunch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2026/04/07 20:14:32 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2026/04/07 20:14:45 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/mlflow/artifacts/1', creation_time=1775585685225, experiment_id='1', last_update_time=1775585685225, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5001/#/experiments/1/runs/0aebbd03d46d49b0844e9595f725ff78
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:5001/#/experiments/1/runs/016fbd5b6e6b49b58dee15881970e932
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:08 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:08 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5001/#/experiments/1/runs/98eeff73005b49a1bf4e91bbcec4327c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 20:16:09 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:10 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:11 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:11 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:12 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/1/runs/6fe221ff3fe94fd3b8aa766355dccad3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 20:16:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 20:16:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 20:16:16 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5001/#/experiments/1/runs/4c51a2519cf645fd97a1fa1c04094513
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ## 2.3 Connecting DVC and MLflow
#
# You've already used DVC to version your dataset in the first part of this lab. Now let's connect DVC metadata with MLflow experiments to create a complete audit trail. When you run experiments, you want to know:
# - Which version of the data was used?
# - Can I reproduce these exact results?
# - What changed between experiments?
#
# By logging DVC metadata in MLflow, you create a link between your data versions and experiment results.

# %% [markdown]
# ### Reading DVC metadata
#
# DVC stores metadata in `.dvc` files. Let's read it:

# %%
import yaml

def get_dvc_metadata(dvc_file_path):
    with open(dvc_file_path, 'r') as f:
        dvc_data = yaml.safe_load(f)
    
    metadata = {
        'md5': dvc_data['outs'][0]['md5'],
        'size': dvc_data['outs'][0]['size'],
        'path': dvc_data['outs'][0]['path']
    }
    return metadata

dvc_metadata = get_dvc_metadata('data/ames_data_2006_2008.parquet.dvc')
print("DVC Metadata:")
print(f"MD5 hash: {dvc_metadata['md5']}")
print(f"File size: {dvc_metadata['size']} bytes")
print(f"Data path: {dvc_metadata['path']}")
# Out:
# DVC Metadata:
# MD5 hash: f44053333f88a0646819936b37f000ee
# File size: 162560 bytes
# Data path: ames_data_2006_2008.parquet

# %% [markdown]
# ### Exercise 1 - Logging DVC metadata in MLflow
#
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Now let's modify our training to include DVC metadata. This creates a complete audit trail:
# - **Git commit** → tracks code version
# - **DVC hash** → tracks data version
# - **MLflow run** → tracks experiment results
#
# Your task is to:
# 1. Run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again.
# 2. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
# 3. Make sure you have included DVC metadata logging. You can initialize dvc_metadata by calling above defined `get_dvc_metadata` function with the .dvc metadata file. Then you can just for each experiment add param logging like:
#
# ```python
# mlflow.log_param("param_name", "value you want to log") # e.g md5
# ```

# %%
# Zad1. Run 5 more experiments with different parameters and models from scikit-learn.
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR

new_models = [
    (
        "Ridge alpha=5.0",
        Ridge(alpha=5.0, random_state=42),
    ),
    (
        "ElasticNet a=0.01 l1=0.3",
        ElasticNet(alpha=0.01, l1_ratio=0.3, random_state=42, max_iter=20000),
    ),
    (
        "RandomForest 300 depth=20",
        RandomForestRegressor(
            n_estimators=300, max_depth=20, min_samples_split=4, random_state=42
        ),
    ),
    (
        "ExtraTrees 300",
        ExtraTreesRegressor(
            n_estimators=300, max_depth=None, min_samples_leaf=2, random_state=42
        ),
    ),
    (
        "SVR RBF C=30",
        SVR(C=30.0, epsilon=0.1, gamma="scale", kernel="rbf"),
    ),
]

print(f"Zdefiniowano {len(new_models)} nowych eksperymentow.")
for model_name, _ in new_models:
    print("-", model_name)
# Out:
# Zdefiniowano 5 nowych eksperymentow.
# - Ridge alpha=5.0
# - ElasticNet a=0.01 l1=0.3
# - RandomForest 300 depth=20
# - ExtraTrees 300
# - SVR RBF C=30

# %%
# Zad2. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
fit_sklearn_models_with_cv(new_models, X_train, X_test, y_train, y_test)
# Out:
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Ridge alpha=5.0:
#   RMSE: 23422.25
#   MAE: 16416.74
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.896 ± 0.029
# 🏃 View run Ridge alpha=5.0 at: http://localhost:5001/#/experiments/1/runs/108663db36a642f19bbfde8d013146e0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:32 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ElasticNet a=0.01 l1=0.3:
#   RMSE: 23720.43
#   MAE: 16565.07
#   R^2: 0.902
#   CV R^2 (mean ± std): 0.894 ± 0.028
# 🏃 View run ElasticNet a=0.01 l1=0.3 at: http://localhost:5001/#/experiments/1/runs/76c72cde7b9c419396ace7b5d8a63851
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:27:35 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:35 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:38 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:40 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:40 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:42 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:45 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:47 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:47 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# RandomForest 300 depth=20:
#   RMSE: 25850.00
#   MAE: 15548.81
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.880 ± 0.048
# 🏃 View run RandomForest 300 depth=20 at: http://localhost:5001/#/experiments/1/runs/bd91bcb4fe1940a69467cbb997921a56
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:27:50 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:50 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:52 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:52 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:54 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:56 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:27:58 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:27:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ExtraTrees 300:
#   RMSE: 23012.48
#   MAE: 14820.70
#   R^2: 0.907
#   CV R^2 (mean ± std): 0.887 ± 0.044
# 🏃 View run ExtraTrees 300 at: http://localhost:5001/#/experiments/1/runs/136e07b9a00346da81f9e5de60779723
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:28:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:28:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:28:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# SVR RBF C=30:
#   RMSE: 76564.37
#   MAE: 53961.42
#   R^2: -0.026
#   CV R^2 (mean ± std): -0.079 ± 0.070
# 🏃 View run SVR RBF C=30 at: http://localhost:5001/#/experiments/1/runs/88e17774c96d4178a3e674cbf109bd6e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %%
# Zad3. Make sure you have included DVC metadata logging.
dvc_metadata = get_dvc_metadata("data/ames_data_2006_2008.parquet.dvc")

results_with_dvc = {}

for model_name, model in new_models:
    with mlflow.start_run(run_name=f"{model_name} + DVC"):
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        rmse = root_mean_squared_error(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        # dolaczenie informacji o wersji danych
        mlflow.log_param("dvc_md5", dvc_metadata["md5"])
        mlflow.log_param("dvc_size", dvc_metadata["size"])
        mlflow.log_param("dvc_path", dvc_metadata["path"])

        # proste metryki do podgladu
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("mae", mae)
        mlflow.log_metric("r2", r2)

        results_with_dvc[model_name] = {
            "rmse": rmse,
            "mae": mae,
            "r2": r2,
            "dvc_md5": dvc_metadata["md5"],
        }

print("Gotowe. W tym bloku przygotowano 5 runow z metadanymi DVC.")
# Out:
# 2026/04/07 21:31:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:31:39 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:31:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 21:31:39 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:31:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 🏃 View run Ridge alpha=5.0 + DVC at: http://localhost:5001/#/experiments/1/runs/9c04a083695c48ab886efe3574b7520c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run ElasticNet a=0.01 l1=0.3 + DVC at: http://localhost:5001/#/experiments/1/runs/bb7036b28fda4984ac4a334d493e0ff4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:31:42 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:31:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 🏃 View run RandomForest 300 depth=20 + DVC at: http://localhost:5001/#/experiments/1/runs/d73c360410e94c3d8242f8be3f5d0319
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:31:45 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/04/07 21:31:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 🏃 View run ExtraTrees 300 + DVC at: http://localhost:5001/#/experiments/1/runs/1990f023df694e8aa28ed66697073129
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 21:31:45 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 🏃 View run SVR RBF C=30 + DVC at: http://localhost:5001/#/experiments/1/runs/3363d47b97124d35808d34c4f8042876
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Gotowe. W tym bloku przygotowano 5 runow z metadanymi DVC.

# %% [markdown]
# ## 3. Manual logging with PyTorch
#
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but we often need low-level control of pure PyTorch.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2026/04/07 21:34:57 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/mlflow/artifacts/2', creation_time=1775590497247, experiment_id='2', last_update_time=1775590497247, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation
#
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them.

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model
#
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        required_keys = ['hidden_units', 'dropout', 'batch_size', 'learning_rate', 
                         'log_interval', 'epochs', 'name']
        missing = [key for key in required_keys if key not in config]
        if missing:
            raise ValueError(f"Missing required config keys: {missing}")
        
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def _log_dvc_metadata(self, dvc_file_path: str = 'data/ames_data_2006_2008.parquet.dvc'):
        try:
            dvc_metadata = get_dvc_metadata(dvc_file_path)
            
            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])
            mlflow.log_param("data_path", dvc_metadata['path'])
            print(f"Logged DVC metadata: {dvc_metadata['md5'][:8]}...")
        except FileNotFoundError:
            print("DVC file not found - skipping metadata logging")
        except Exception as e:
            print(f"Could not log DVC metadata: {e}")

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)
            
            # Log DVC metadata for data versioning
            self._log_dvc_metadata()

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.
#
# ### Configuration
# `base_config` contains **fixed parameters** that stay the same across all experiments:
# - `model_class`: The neural network architecture we're using (HousePriceNet)
# - `random_seed`: For reproducibility (42)
# - `log_interval`: How often to log metrics during training (every 5 epochs)
# - `num_samples`: Dataset size
# - `input_features`: Number of input features
# - `k_folds`: Number of cross-validation folds (5)
#
# `experiment_config` contains **hyperparameters** we want to tune:
# - `name`: Unique identifier for this experiment run
# - `hidden_units`: Size of the hidden layer (128, 256, 512, etc.)
# - `dropout`: Dropout rate for regularization (0.0 to 0.5)
# - `learning_rate`: Step size for gradient descent (0.001 to 0.1)
# - `epochs`: Number of training iterations (50, 100, 150, etc.)
# - `batch_size`: Number of samples per training batch (16, 32, 64, etc.)
#
# If you want you can deliver your own NeuralNetwork model, and just specify in experiment_config: `{"model_class": YourOwnModel}` it will overwrite the our base `HousePriceNet`

# %% [markdown]
# #### 3. Merging configurations
# We use Python's dictionary merge operator `|` to combine them:
# ```python
# training_config = base_config | experiment_config
# ```
#
# This creates a single configuration dictionary with all parameters. The `experiment_config` values override any duplicate keys from `base_config`, allowing us to easily experiment with different hyperparameters while keeping the base setup constant.
#
# Now let's set up our first experiment:

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

experiment_config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | experiment_config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 93358.66, MAE: 74539.00 R^2: -0.208
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 43615.34, MAE: 34606.44 R^2: 0.688
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24469.80, MAE: 16723.66 R^2: 0.911
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 32777.56, MAE: 24079.62 R^2: 0.812
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 26063.38, MAE: 18416.14 R^2: 0.883
#
# Cross-validation complete. Mean R^2: 0.617 (+/- 0.420)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.617 (+/- 0.420)
#
# Cross-Validation Performance:
#   R^2: 0.862
#   RMSE: 28091.03
#   MAE: 19802.32
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5001/#/experiments/2/runs/61f7924391774064b2e539bbda32d1de
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# {'rmse': 28091.029296875,
#  'mae': 19802.318359375,
#  'r2': 0.86189204454422,
#  'cv_r2_mean': np.float64(0.6172545671463012),
#  'cv_r2_std': np.float64(0.4196082501022651),
#  'cv_scores': [-0.20772981643676758,
#   0.6881988048553467,
#   0.9107953310012817,
#   0.8119579553604126,
#   0.8830505609512329]}

# %% [markdown]
# ### Exercise 2
#
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# **How to modify configurations:**
#
# You have two approaches:
#
# #### Approach 1: Loop through multiple configurations (Recommended for systematic exploration)
#
# Define a list of experiment configurations and iterate through them. Each configuration dictionary should contain only the hyperparameters you want to tune (name, hidden_units, dropout, learning_rate, epochs, batch_size). The base_config stays the same.
#
# ```python
# base_config = {
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],  # Number of features (181)
#     "num_samples": X_train.shape[0],     # Dataset size (1312)
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# # Define multiple experiments to run
# configs = [
#     {
#         "name": "baseline_128_units",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     {
#         "name": "larger_network_256",
#         "hidden_units": 256,        # Try larger network
#         "dropout": 0.2,             # More dropout for regularization
#         "learning_rate": 0.01,      # Lower learning rate
#         "epochs": 200,
#         "batch_size": 64,
#     },
#     {
#         "name": "high_regularization",
#         "hidden_units": 128,
#         "dropout": 0.3,             # Even more dropout
#         "learning_rate": 0.01,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     # Add 7 more configurations here...
# ]
#
# # Run all experiments
# for experiment_config in configs:
#     training_config = base_config | experiment_config
#
#     trainer = PyTorchTrainer(training_config["model_class"], training_config)
#     results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
#
# #### Approach 2: Manual and incremental (Good for quick iterations)
#
# Run experiments one by one, adjusting hyperparameters based on previous results:
#
# ```python
# # First experiment
# experiment_config = {
#     "name": "experiment_01_baseline",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
# After analyzing results in MLflow, run another experiment
#
# ```
# experiment_config = {
#     "name": "experiment_02_more_dropout",
#     "hidden_units": 128,
#     "dropout": 0.3,  # Increased from 0.1
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
#
# # Continue with more experiments
# ```

# %% [markdown]
# **Tips for hyperparameter tuning:**
# - Start with one change at a time to understand its impact
# - Use meaningful experiment names that describe what you changed
# - Check MLflow UI after each experiment to guide your next choice
# - Look for signs of overfitting: high training performance but poor test performance
# - Watch the training curves in MLflow's "Model metrics" tab

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
# Zad1.
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "input_features": X_train.shape[1],
    "num_samples": X_train.shape[0],
    "target_normalized": True,
    "k_folds": 5,
}

configs = [
    {
        "name": "exp01_baseline_128_d10_lr003",
        "hidden_units": 128,
        "dropout": 0.10,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "exp02_more_dropout_d25",
        "hidden_units": 128,
        "dropout": 0.25,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "exp03_strong_dropout_d35",
        "hidden_units": 128,
        "dropout": 0.35,
        "learning_rate": 0.02,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "exp04_smaller_net_64",
        "hidden_units": 64,
        "dropout": 0.20,
        "learning_rate": 0.02,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "exp05_larger_net_256",
        "hidden_units": 256,
        "dropout": 0.30,
        "learning_rate": 0.01,
        "epochs": 180,
        "batch_size": 64,
    },
    {
        "name": "exp06_lower_lr_longer_train",
        "hidden_units": 128,
        "dropout": 0.20,
        "learning_rate": 0.005,
        "epochs": 220,
        "batch_size": 32,
    },
    {
        "name": "exp07_bigger_batch_128",
        "hidden_units": 128,
        "dropout": 0.20,
        "learning_rate": 0.01,
        "epochs": 180,
        "batch_size": 128,
    },
    {
        "name": "exp08_small_batch_16",
        "hidden_units": 128,
        "dropout": 0.15,
        "learning_rate": 0.01,
        "epochs": 180,
        "batch_size": 16,
    },
    {
        "name": "exp09_64units_d30_lr005",
        "hidden_units": 64,
        "dropout": 0.30,
        "learning_rate": 0.005,
        "epochs": 220,
        "batch_size": 64,
    },
    {
        "name": "exp10_256units_d20_lr005",
        "hidden_units": 256,
        "dropout": 0.20,
        "learning_rate": 0.005,
        "epochs": 220,
        "batch_size": 64,
    },
]

print(f"Przygotowano {len(configs)} konfiguracji.")
print("Pierwsza konfiguracja:", configs[0]["name"])
print("Ostatnia konfiguracja:", configs[-1]["name"])
# Out:
# Przygotowano 10 konfiguracji.
# Pierwsza konfiguracja: exp01_baseline_128_d10_lr003
# Ostatnia konfiguracja: exp10_256units_d20_lr005

# %%
# Running all experiments
all_results = []

for i, experiment_config in enumerate(configs, start=1):
    training_config = base_config | experiment_config
    print(f"\n[{i}/{len(configs)}] Running: {training_config['name']}")

    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)

    all_results.append({
        "name": training_config["name"],
        "hidden_units": training_config["hidden_units"],
        "dropout": training_config["dropout"],
        "learning_rate": training_config["learning_rate"],
        "epochs": training_config["epochs"],
        "batch_size": training_config["batch_size"],
        "test_rmse": results["rmse"],
        "test_mae": results["mae"],
        "test_r2": results["r2"],
        "cv_r2_mean": results["cv_r2_mean"],
        "cv_r2_std": results["cv_r2_std"],
    })

results_df = pd.DataFrame(all_results)
results_df
# Out:
# [1/10] Running: exp01_baseline_128_d10_lr003
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp01_baseline_128_d10_lr003...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23529.76, MAE: 17298.58 R^2: 0.923
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 64342.03, MAE: 47700.14 R^2: 0.321
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23553.19, MAE: 17048.56 R^2: 0.917
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 27571.10, MAE: 19084.94 R^2: 0.867
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 47019.47, MAE: 37633.79 R^2: 0.619
#
# Cross-validation complete. Mean R^2: 0.730 (+/- 0.233)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.730 (+/- 0.233)
#
# Cross-Validation Performance:
#   R^2: 0.900
#   RMSE: 23874.16
#   MAE: 15909.52
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp01_baseline_128_d10_lr003:
#
# ==================================================
# 🏃 View run exp01_baseline_128_d10_lr003 at: http://localhost:5001/#/experiments/2/runs/02ca36f33a9b410ba9a6d10361b00a38
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [2/10] Running: exp02_more_dropout_d25
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp02_more_dropout_d25...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22994.28, MAE: 16193.35 R^2: 0.927
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 19998.12, MAE: 13967.84 R^2: 0.934
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24913.81, MAE: 17094.64 R^2: 0.908
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 26410.86, MAE: 18259.82 R^2: 0.878
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 25046.41, MAE: 17972.82 R^2: 0.892
#
# Cross-validation complete. Mean R^2: 0.908 (+/- 0.021)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.908 (+/- 0.021)
#
# Cross-Validation Performance:
#   R^2: 0.881
#   RMSE: 26062.23
#   MAE: 18335.85
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp02_more_dropout_d25:
#
# ==================================================
# 🏃 View run exp02_more_dropout_d25 at: http://localhost:5001/#/experiments/2/runs/54839824d6534cdaa1eb71d622c83a4f
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [3/10] Running: exp03_strong_dropout_d35
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp03_strong_dropout_d35...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22714.88, MAE: 15654.41 R^2: 0.929
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 20081.12, MAE: 14233.50 R^2: 0.934
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 28597.44, MAE: 18566.60 R^2: 0.878
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 22768.12, MAE: 15684.29 R^2: 0.909
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24059.19, MAE: 16433.22 R^2: 0.900
#
# Cross-validation complete. Mean R^2: 0.910 (+/- 0.020)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.910 (+/- 0.020)
#
# Cross-Validation Performance:
#   R^2: 0.907
#   RMSE: 23010.18
#   MAE: 16013.79
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp03_strong_dropout_d35:
#
# ==================================================
# 🏃 View run exp03_strong_dropout_d35 at: http://localhost:5001/#/experiments/2/runs/4b1e805899e54a0bb831430ddfb4dc28
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [4/10] Running: exp04_smaller_net_64
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp04_smaller_net_64...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22994.18, MAE: 16185.44 R^2: 0.927
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 20675.15, MAE: 14127.72 R^2: 0.930
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24457.62, MAE: 16208.16 R^2: 0.911
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 21625.73, MAE: 14849.71 R^2: 0.918
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 22311.78, MAE: 15408.78 R^2: 0.914
#
# Cross-validation complete. Mean R^2: 0.920 (+/- 0.007)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.920 (+/- 0.007)
#
# Cross-Validation Performance:
#   R^2: 0.908
#   RMSE: 22926.25
#   MAE: 15736.75
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp04_smaller_net_64:
#
# ==================================================
# 🏃 View run exp04_smaller_net_64 at: http://localhost:5001/#/experiments/2/runs/7108a17942c2467ab1bf309dd4b95a36
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [5/10] Running: exp05_larger_net_256
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp05_larger_net_256...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 52341.90, MAE: 39113.35 R^2: 0.620
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 108262.88, MAE: 82384.88 R^2: -0.921
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 67859.37, MAE: 46469.10 R^2: 0.314
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 58732.23, MAE: 38990.34 R^2: 0.396
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 51561.70, MAE: 37936.45 R^2: 0.542
#
# Cross-validation complete. Mean R^2: 0.190 (+/- 0.566)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.190 (+/- 0.566)
#
# Cross-Validation Performance:
#   R^2: 0.011
#   RMSE: 75185.46
#   MAE: 62111.07
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp05_larger_net_256:
#
# ==================================================
# 🏃 View run exp05_larger_net_256 at: http://localhost:5001/#/experiments/2/runs/cdfd69d7342f47289fa8675b18b949bf
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [6/10] Running: exp06_lower_lr_longer_train
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp06_lower_lr_longer_train...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 55713.80, MAE: 43512.73 R^2: 0.570
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 46617.52, MAE: 32292.24 R^2: 0.644
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 64278.67, MAE: 50763.84 R^2: 0.384
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 44947.95, MAE: 32749.80 R^2: 0.646
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 31730.69, MAE: 23069.54 R^2: 0.827
#
# Cross-validation complete. Mean R^2: 0.614 (+/- 0.143)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.614 (+/- 0.143)
#
# Cross-Validation Performance:
#   R^2: 0.832
#   RMSE: 30959.60
#   MAE: 21224.14
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp06_lower_lr_longer_train:
#
# ==================================================
# 🏃 View run exp06_lower_lr_longer_train at: http://localhost:5001/#/experiments/2/runs/37ffddb38f1b40cc9973da124749e9bf
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [7/10] Running: exp07_bigger_batch_128
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp07_bigger_batch_128...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 113237.97, MAE: 85164.48 R^2: -0.777
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 59028.67, MAE: 48542.97 R^2: 0.429
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 50442.18, MAE: 40527.98 R^2: 0.621
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 117865.21, MAE: 84518.18 R^2: -1.431
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 48983.72, MAE: 37899.83 R^2: 0.587
#
# Cross-validation complete. Mean R^2: -0.114 (+/- 0.837)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.114 (+/- 0.837)
#
# Cross-Validation Performance:
#   R^2: 0.628
#   RMSE: 46112.48
#   MAE: 31938.22
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp07_bigger_batch_128:
#
# ==================================================
# 🏃 View run exp07_bigger_batch_128 at: http://localhost:5001/#/experiments/2/runs/7c3d2996553841e8837d63c1ee4ca475
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [8/10] Running: exp08_small_batch_16
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp08_small_batch_16...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 25454.12, MAE: 17195.16 R^2: 0.910
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25215.05, MAE: 18631.81 R^2: 0.896
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23183.47, MAE: 16198.67 R^2: 0.920
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 27882.51, MAE: 16905.09 R^2: 0.864
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24389.69, MAE: 16610.33 R^2: 0.898
#
# Cross-validation complete. Mean R^2: 0.897 (+/- 0.019)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.897 (+/- 0.019)
#
# Cross-Validation Performance:
#   R^2: 0.885
#   RMSE: 25651.97
#   MAE: 19140.32
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp08_small_batch_16:
#
# ==================================================
# 🏃 View run exp08_small_batch_16 at: http://localhost:5001/#/experiments/2/runs/1508a5aa56264077bbd39da2ea6943b5
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [9/10] Running: exp09_64units_d30_lr005
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp09_64units_d30_lr005...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 41918.07, MAE: 31843.42 R^2: 0.757
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 84395.47, MAE: 73400.59 R^2: -0.167
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 50961.93, MAE: 37662.02 R^2: 0.613
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 43266.10, MAE: 31174.65 R^2: 0.672
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 36455.59, MAE: 27231.62 R^2: 0.771
#
# Cross-validation complete. Mean R^2: 0.529 (+/- 0.353)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.529 (+/- 0.353)
#
# Cross-Validation Performance:
#   R^2: 0.821
#   RMSE: 32002.14
#   MAE: 22991.01
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp09_64units_d30_lr005:
#
# ==================================================
# 🏃 View run exp09_64units_d30_lr005 at: http://localhost:5001/#/experiments/2/runs/df2625a30d4c46df933763224fd36f60
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# [10/10] Running: exp10_256units_d20_lr005
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for exp10_256units_d20_lr005...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 66736.75, MAE: 50323.76 R^2: 0.383
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 59165.19, MAE: 48867.96 R^2: 0.426
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 48608.86, MAE: 34672.29 R^2: 0.648
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 62849.92, MAE: 47631.62 R^2: 0.309
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 55221.40, MAE: 44407.97 R^2: 0.475
#
# Cross-validation complete. Mean R^2: 0.448 (+/- 0.114)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.448 (+/- 0.114)
#
# Cross-Validation Performance:
#   R^2: 0.756
#   RMSE: 37341.84
#   MAE: 26912.24
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp10_256units_d20_lr005:
#
# ==================================================
# 🏃 View run exp10_256units_d20_lr005 at: http://localhost:5001/#/experiments/2/runs/4e11d513971c4730a4d308c01e798db4
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#                            name  hidden_units  dropout  learning_rate  epochs  \
# 0  exp01_baseline_128_d10_lr003           128     0.10          0.030     150
# 1        exp02_more_dropout_d25           128     0.25          0.030     150
# 2      exp03_strong_dropout_d35           128     0.35          0.020     150
# 3          exp04_smaller_net_64            64     0.20          0.020     150
# 4          exp05_larger_net_256           256     0.30          0.010     180
# 5   exp06_lower_lr_longer_train           128     0.20          0.005     220
# 6        exp07_bigger_batch_128           128     0.20          0.010     180
# 7          exp08_small_batch_16           128     0.15          0.010     180
# 8       exp09_64units_d30_lr005            64     0.30          0.005     220
# 9      exp10_256units_d20_lr005           256     0.20          0.005     220
#
#    batch_size     test_rmse      test_mae   test_r2  cv_r2_mean  cv_r2_std
# 0          32  23874.160156  15909.516602  0.900244    0.729681   0.232540
# 1          32  26062.226562  18335.851562  0.881121    0.907725   0.021031
# 2          32  23010.181641  16013.791016  0.907333    0.910037   0.020106
# 3          32  22926.250000  15736.747070  0.908008    0.919999   0.007255
# 4          64  75185.460938  62111.074219  0.010647    0.190348   0.566014
# 5          32  30959.597656  21224.136719  0.832246    0.614238   0.142688
# 6         128  46112.480469  31938.224609  0.627848   -0.114317   0.836810
# 7          16  25651.972656  19140.316406  0.884834    0.897491   0.018946
# 8          64  32002.142578  22991.007812  0.820757    0.529142   0.353011
# 9          64  37341.843750  26912.240234  0.755952    0.448143   0.113901

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Analiza wyników:
#
# 10 runów eksperymentu PyTorch w widoku Compare Runs.
#
# Najlepsze konfiguracje to:
#
# exp04_smaller_net_64
# * test_rmse: ~22926.25
# * test_mae: ~15736.75
# * test_r2: ~0.9080
#
# exp03_strong_dropout_d35
# * test_rmse: ~23010.18
# * test_mae: ~16013.79
# * test_r2: ~0.9073
#
# exp01_baseline_128_d10_lr003
# * test_rmse: ~23874.16
# * test_mae: ~15909.52
# * test_r2: ~0.9002
#
#
# Parametry wpływające
# Pomagają:
# Zmniejszenie pojemności modelu (hidden_units=64)
# Mocniejsza regularyzacja dropout (0.35)

# %% [markdown]
# Porównanie sklearn z pytorch
#
# sklearn:
# * cv_r2_mean	0.895014461408796
# * cv_r2_std	    0.034710437918173895
# * alpha	1.0
#
# pytorch
# * cv_r2_mean	0.6172545671463012
# * cv_r2_std	    0.4196082501022651
# * test_r2	    0.86189204454422
# * final_model_train_mse	0.025943043687176412
#
#
# final_model_train_mse jest bardzo niski - model nauczył się danych treningowych. Bardzo słabo wyszło na nowych danych cv_r2_mean	0.6172545671463012
